# %%
import pandas as pd
import sys
sys.path.append('../programs')  # Update with the actual path

from download_lagacy_imagescoloured_v2 import main, download_legacy

# %%
# Load training, validation, and test set CSV files
train_data = pd.read_csv('../Datasets_DeepShadows/Datasets/Baseline_training.csv')
val_data = pd.read_csv('../Datasets_DeepShadows/Datasets/Baseline_validation.csv')
test_data = pd.read_csv('../Datasets_DeepShadows/Datasets/Baseline_test.csv')

# %% [markdown]
# ##### Descragando las imégenes

# %%
# Specify the absolute path to save the downloaded files
output_folder = '../Datasets_DeepShadows/Jpeg_data/Training/'  # Update with the actual path
default_radii = 128

# %%
# Run the main function
if __name__ == "__main__":
    download_legacy(train_data, output_folder, default_radii)
# Out:
# INFO: Downloading image for 26.108572_-6.439318
# INFO: Downloading image for 45.534353_-37.171315
# INFO: Downloading image for 42.025593_-11.286475
# INFO: Downloading image for 11.829991_-24.476106
# INFO: Downloading image for 16.885239000000002_-19.114691
# INFO: Downloading image for 69.961617_-22.890477
# INFO: Downloading image for 21.570075_-37.809098
# INFO: Downloading image for 342.379688_-51.244724
# INFO: Downloading image for 351.299344_-1.783148
# INFO: Downloading image for 54.517884_-31.571131
# INFO: Downloading image for 57.266479_-29.196071000000003
# INFO: Downloading image for 314.393454_-48.422501
# INFO: Downloading image for 40.799294_-29.386695
# INFO: Downloading image for 0.287785_-57.503674
# INFO: Downloading image for 21.419633_-3.536368
# INFO: Downloading image for 352.821706_-57.913749
# INFO: Downloading image for 325.032212_-41.458424
# INFO: Downloading image for 53.914844_-40.497365
# INFO: Downloading image for 40.730667_-29.811048
# ...
